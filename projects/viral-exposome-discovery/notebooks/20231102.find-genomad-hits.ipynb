# %% [markdown]
# objectives
# - find the what contigs were classified as viral by genomad
# - determine the lengths
# - find alignments in NCBI blast

# %%
import Pkg
pkgs = [
    "Revise",
    "DataFrames",
    "ProgressMeter",
    "uCSV",
    "StatsPlots",
    "StatsBase",
    "FASTX"
]
# Pkg.activate(; temp=true)
# Pkg.add(pkgs)
for pkg in pkgs
    eval(Meta.parse("import $pkg"))
end
import Mycelia
# Out:
# [ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# [ Info: Precompiling IJuliaExt [2f4121a4-3b3a-5ce6-9c5e-1f2673ce168a]
# [ Info: Precompiling Mycelia [453d265d-8292-4a7b-a57c-dce3f9ae6acd]
# [ Info: Skipping precompilation since __precompile__(false). Importing Mycelia [453d265d-8292-4a7b-a57c-dce3f9ae6acd].
# [ Info: Precompiling FileIOExt [f5f51d8f-5827-5d2e-939b-192fcd6ec70c]
# [ Info: Precompiling GeometryBasicsExt [b238bd29-021f-5edc-8b0e-16b9cda5f63a]

# %%
base_dir = dirname(pwd())
data_dir = joinpath(base_dir, "data")
sample_directories = readdir(joinpath(data_dir, "SRA"), join=true)
# Out:
# 594-element Vector{String}:
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399459"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399460"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399461"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399462"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399463"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399464"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399465"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399466"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399467"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399468"
#  "/oak/stanford/scg/lab_mpsnyder/" ⋯ 39 bytes ⋯ "e-discovery/data/SRA/SRR6399469"
# ...

# %%
joint_genomad_results = DataFrames.DataFrame()
# sample_directory = first(sample_directories)
ProgressMeter.@showprogress for sample_directory in sample_directories
    genomad_virus_summary = joinpath(sample_directory, "genomad", "final.contigs.fastg.gfa_summary", "final.contigs.fastg.gfa_virus_summary.tsv")
    genomad_results = DataFrames.DataFrame(uCSV.read(genomad_virus_summary, delim='\t', header=1, typedetectrows=100)...)
    genomad_results[!, "sample_id"] .= basename(sample_directory)
    append!(joint_genomad_results, genomad_results, promote=true)
end
joint_genomad_results[!, "seq_name"] = string.(joint_genomad_results[!, "seq_name"])
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:24
# 28174-element Vector{String}:
#  "2192"
#  "5483"
#  "5222"
#  "6800"
#  "2732"
#  "10553"
#  "922"
#  "2242"
#  "10765"
#  "14533"
#  "9355"
#  "1385"
#  "8067"
#  ⋮
#  "24977"
#  "92194"
#  "130274"
#  "12028"
#  "3455"
#  "147652"
#  "103716"
#  "9641"
#  "2409"
#  "1688"
#  "3313"
#  "6632"

# %%
StatsBase.describe(joint_genomad_results[!, "length"])

# %%
# StatsPlots.scatter(
#     joint_genomad_results[!, "length"],
#     joint_genomad_results[!, "virus_score"],
#     legend=false)

# %%
# for x in sort(unique(joint_genomad_results[!, "taxonomy"]))
#     println(x)
# end

# %% [markdown]
# ```
# # vertebrates
# Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Alloherpesviridae
# Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Papovaviricetes;Sepolyvirales;Polyomaviridae
# Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Papovaviricetes;Zurhausenvirales;Papillomaviridae
# Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Quintoviricetes;Piccovirales;Parvoviridae
# Viruses;Monodnaviria;Shotokuvirae;Cressdnaviricota;Arfiviricetes;Cirlivirales;Circoviridae
# Viruses;Monodnaviria;Shotokuvirae;Cressdnaviricota;Arfiviricetes;Cremevirales;Smacoviridae
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Alsuviricetes;Martellivirales;Togaviridae
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Flasuviricetes;Amarillovirales;Flaviviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Insthoviricetes;Articulavirales;Orthomyxoviridae
# Viruses;Riboviria;Orthornavirae;Pisuviricota;Stelpaviricetes;Stellavirales;Astroviridae
# Viruses;Riboviria;Pararnavirae;Artverviricota;Revtraviricetes;Ortervirales;Retroviridae
# Viruses;Varidnaviria;Bamfordvirae;Preplasmiviricota;Tectiliviricetes;Rowavirales;Adenoviridae
# # mammals
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Alsuviricetes;Hepelivirales;Hepeviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales;Nairoviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales;Phenuiviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Bornaviridae
# Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales;Caliciviridae
# # human
# Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Herpesviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales
# # vertebrates and invertebrates
# Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Malacoherpesviridae
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Magsaviricetes;Nodamuvirales;Nodaviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Paramyxoviridae
# Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales;Picornaviridae
# Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Pokkesviricetes;Chitovirales;Poxviridae
# # non-specific
# Viruses;Riboviria;Orthornavirae;Duplornaviricota;Resentoviricetes;Reovirales;Sedoreoviridae
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes
# Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Rhabdoviridae
# Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales
# # eukaryotes
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;
# Viruses;Varidnaviria;Bamfordvirae;Preplasmiviricota;Maveriviricetes;Priklausovirales;Lavidaviridae
# #algae
# Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Megaviricetes;Algavirales;Phycodnaviridae
# #amoeba
# Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Megaviricetes;Imitervirales;Mimiviridae
# # unsure
# Viruses;Duplodnaviria;Heunggongvirae;Uroviricota;Caudoviricetes;Peduoviridae
# Viruses;Riboviria;Orthornavirae;Duplornaviricota;Resentoviricetes;Reovirales;Spinareoviridae
# Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Alsuviricetes;Martellivirales
# Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Sobelivirales;Solemoviridae
# Viruses;Varidnaviria;Bamfordvirae;Preplasmiviricota;Polintoviricetes;Orthopolintovirales;Adintoviridae
# Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Megaviricetes;Pimascovirales
# Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Megaviricetes;Pimascovirales;Pimascovirales
# ```

# %%
taxa_of_interst = 
[
    # human
    "Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Herpesviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales",
    # vertebrates
    "Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Alloherpesviridae",
    "Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Papovaviricetes;Sepolyvirales;Polyomaviridae",
    "Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Papovaviricetes;Zurhausenvirales;Papillomaviridae",
    "Viruses;Monodnaviria;Shotokuvirae;Cossaviricota;Quintoviricetes;Piccovirales;Parvoviridae",
    "Viruses;Monodnaviria;Shotokuvirae;Cressdnaviricota;Arfiviricetes;Cirlivirales;Circoviridae",
    "Viruses;Monodnaviria;Shotokuvirae;Cressdnaviricota;Arfiviricetes;Cremevirales;Smacoviridae",
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Alsuviricetes;Martellivirales;Togaviridae",
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Flasuviricetes;Amarillovirales;Flaviviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Insthoviricetes;Articulavirales;Orthomyxoviridae",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Stelpaviricetes;Stellavirales;Astroviridae",
    "Viruses;Riboviria;Pararnavirae;Artverviricota;Revtraviricetes;Ortervirales;Retroviridae",
    "Viruses;Varidnaviria;Bamfordvirae;Preplasmiviricota;Tectiliviricetes;Rowavirales;Adenoviridae",
    # mammals
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Alsuviricetes;Hepelivirales;Hepeviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales;Nairoviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales;Phenuiviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Bornaviridae",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales;Caliciviridae",
    # vertebrates and invertebrates
    "Viruses;Duplodnaviria;Heunggongvirae;Peploviricota;Herviviricetes;Herpesvirales;Malacoherpesviridae",
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Magsaviricetes;Nodamuvirales;Nodaviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Paramyxoviridae",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales;Picornaviridae",
    "Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Pokkesviricetes;Chitovirales;Poxviridae",
    # non-specific
    "Viruses;Riboviria;Orthornavirae;Duplornaviricota;Resentoviricetes;Reovirales;Sedoreoviridae",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Ellioviricetes;Bunyavirales",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes",
    "Viruses;Riboviria;Orthornavirae;Negarnaviricota;Monjiviricetes;Mononegavirales;Rhabdoviridae",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Pisoniviricetes;Picornavirales",
    # eukaryotes
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota",
    "Viruses;Riboviria;Orthornavirae;Kitrinoviricota;Magsaviricetes;Nodamuvirales;Sinhaliviridae",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Duplopiviricetes;Durnavirales",
    "Viruses;Riboviria;Orthornavirae;Pisuviricota;Stelpaviricetes",
    "Viruses;Varidnaviria;Bamfordvirae;Nucleocytoviricota;Megaviricetes;Pimascovirales;Marseilleviridae",
]

genomad_hits_of_interest = sort(joint_genomad_results[map(x -> x in taxa_of_interst, joint_genomad_results[!, "taxonomy"]), :], "virus_score", rev=true)
# Out:
# 1086×12 DataFrame
#   Row │ seq_name  length  topology             coordinates  n_genes  genetic_c ⋯
#       │ String    Int64   String               String       Int64    Int64     ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ 39448       6171  No terminal repeats  NA                 8            ⋯
#     2 │ 10630        537  DTR                  NA                 2
#     3 │ 19639       2098  DTR                  NA                 2
#     4 │ 32691       1943  No terminal repeats  NA                 3
#     5 │ 3142        1480  No terminal repeats  NA                 1            ⋯
#     6 │ 23168       2219  No terminal repeats  NA                 4
#     7 │ 4561         583  No terminal repeats  NA                 2
#     8 │ 11405        702  No terminal repeats  NA                 1
#     9 │ 1117        3313  No terminal repeats  NA                 1            ⋯
# ...

# %%
records_to_blast = Dict()
ProgressMeter.@showprogress for g in DataFrames.groupby(genomad_hits_of_interest, "sample_id")
    sample_id = g[1, "sample_id"]
    seq_ids = Set(string.(g[!, "seq_name"]))
    fasta_file = joinpath(data_dir, "SRA", sample_id, "megahit", "final.contigs.fastg.gfa.fna")
    fasta_records = collect(Mycelia.open_fastx(fasta_file))
    fasta_records = filter(record -> string(FASTX.identifier(record)) in seq_ids, fasta_records)
    records_to_blast[sample_id] = fasta_records
end

# %%
# confirmed
# i = 1 HPV
# i = 4 HPV
# skip
# i = 2 bee virus
# i = 3 unsure
# i = 5 unsure
# i = 6 possible retrovirus
# i = 7 ant hit
# i = 8 MAG: Tombusviridae sp. isolate R34-k141_822469
# i = 9 unsure
# i = 10 ?
# i = 11 ?
hit = genomad_hits_of_interest[i, :]

# %%
# SRR6399806
# SRR6399918
# genomad_hits_of_interest[4, :]

# %%
record = first(filter(record -> FASTX.identifier(record) == hit["seq_name"], records_to_blast[hit["sample_id"]]))
println(record)
